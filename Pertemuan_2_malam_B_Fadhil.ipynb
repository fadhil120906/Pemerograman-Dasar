# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhil120906/Pemerograman-Dasar/blob/main/Pertemuan_2_malam_B_Fadhil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tugas pertemuan 2

#latihan 1
tegangan_panel_surya = "18volt"
arus_panel_surya = "6ampere"
jenis_sel_panel_surya = "monocrystalline"

print ((tegangan_panel_surya),(arus_panel_surya),(jenis_sel_panel_surya))
# Out:
# 18volt 6ampere monocrystalline

# %%
#Latihan 2
jumlah_kaki = 3
resistansi_ohm = 4.7
komponen_aktif = True
nama_komponen = "Transistor BC547"

print(jumlah_kaki, type(jumlah_kaki))
print(resistansi_ohm, type(resistansi_ohm))
print(komponen_aktif, type(komponen_aktif))
print(nama_komponen, type(nama_komponen))
# Out:
# 3 <class 'int'>
# 4.7 <class 'float'>
# True <class 'bool'>
# Transistor BC547 <class 'str'>

# %%
#Latihan 3
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
#Latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) pembacaan pertama dan terakhir
print(tegangan_harian[0])
print(tegangan_harian[-1])

# (b) tambah pembacaan baru
tegangan_harian.append(222.0)

# (c) jumlah total data
print(len(tegangan_harian))
# Out:
# 217.5
# 216.9
# 7

# %%
#Latihan 5
motor = {
    "nama": "Spesifikasi Motor Listrik",
    "daya_kW": 15,
    "tegangan_V": 380,
    "rpm": 1450
}
print(motor["nama"])
motor["rpm"] = 1500
print(motor)
# Out:
# Spesifikasi Motor Listrik
# {'nama': 'Spesifikasi Motor Listrik', 'daya_kW': 15, 'tegangan_V': 380, 'rpm': 1500}

# %%
#Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]


print(pembangkit[1]["nama"])

pembangkit[2]["status"] = "operasi"

pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 120, "status": "standby"})

print(pembangkit)
# Out:
# Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'standby'}]
